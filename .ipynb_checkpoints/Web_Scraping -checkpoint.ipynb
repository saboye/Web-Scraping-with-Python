# %% [markdown]
# ### Web Scraping

# %%
from bs4 import BeautifulSoup                    # HTML parsing
from IPython.display import Image                # image display
import os                                        # mkdir(), listdir()
import requests                                  # HTTP connection
import time                                      # sleep() function

# %% [markdown]
# ### Fetching HTML content from a webpage using Requests

# %% [markdown]
# **[What The Polls Say About Impeachment Before The First Public Hearing](https://fivethirtyeight.com/features/what-the-polls-say-about-impeachment-before-the-first-public-hearing/)**

# %%
url = "https://fivethirtyeight.com/features/what-weve-already-learned-from-the-democrats-impeachment-witnesses/"
r = requests.get(url)

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US" class="no-js">\n<head>\n\t<meta charset="UTF-8">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\t\t<title>The Democrats&#8217; Impeachment Witnesses | FiveThirtyEight</title>\n<!-- Jetpack Site Verification Tags -->\n\t\t\t\t\t<link\n\t\t\trel="preload"\n\t\t\tas="font"\n\t\t\ttype="font/woff2"\n\t\t\thref="wp-content/themes/espn-fivethirtyeight/assets/fonts/AtlasGrotesk-Bold-Web.woff2"\n\t\t\tcrossorigin="anonymous">\n\t\t\t\t\t<link\n\t\t\trel="preload"\n\t\t\tas="font"\n\t\t\ttype="font/woff2"\n\t\t\thref="wp-content/themes/espn-fivethirtyeight/assets/fonts/AtlasGrotesk-Regular-Web.woff2"\n\t\t\tcrossorigin="anonymous">\n\t\t\t\t\t<link\n\t\t\trel="preload"\n\t\t\tas="font"\n\t\t\ttype="font/woff2"\n\t\t\thref="wp-content/themes/espn-fivethirtyeight/assets/fonts/decimamonopro-webfont.woff2"\n\t\t\tcrossorigin="anonymous">\n\t\t\t\t<link rel=\'dns-prefetch\' href=\'//cdn.registerdisney.go.com\' />\n<link rel=\'dns-prefetch\' href=\'//platform.twitter.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel=\'dns-prefetch\' href=\'//pagead2.googlesyndication.com\' />\n<link rel=\'dns-prefetch\' href=\'//tpc.googlesyndication.com\' />\n<link rel=\'dns-prefetch\' href=\'//securepubads.g.doubleclick.net\' />\n<link rel=\'dns-prefetch\' href=\'//www.googletagmanager.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.googletagservices.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.googleadservices.com\' />\n<link rel=\'dns-prefetch\' href=\'//adservice.google.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.google.com\' />\n<link rel=\'stylesheet\' id=\'all-css-0\' href=\'https://fivethirtyeight.com/_static/??-eJxtzeEKwjAMBOAXsgsyJ/SH+Cxdl3XBLC1LpvTtLYggw9939x28iiOJvE+oEFVhIjUYOceHYxq3sFVQq4zdStK1wgnaImYxFIPCeyJRSDS7wqG6cTfLAkEV7eMdor+MLbi2e9QibqYn2kKbVaS02C91iL7Ufb2dBz/0vffXyxsxM027\' type=\'text/css\' media=\'all\' />\n<style id=\'wp-block-library-inline-css\'>\n.has-text-align-justify{text-align:justify;}\n</style>\n<script>\nvar DisneyOneID = {"config":{"clientId":"DATG-FIVETHIRTYEIGHT.WEB-PROD","langPref":"en-US","debug":false,"responderPage":"https:\\/\\/fivethirtyeight.com\\/oneid-responder","campaignName":"FiveThirtyEight"}};\n</script>\n<script src=\'https://cdn.registerdisney.go.com/v2/outer/DisneyID.js\'></script>\n<script>\nvar ESPNTaboola = {"publisher":"abcnews-fivethirtyeight","type":"article"};\n</script>\n<script type=\'text/javascript\' src=\'https://fivethirtyeight.com/_static/??-\'></script>\n<script async="async" defer="defer" src=\'https://platform.twitter.com/widgets.js?ver=1.0.23\'></script>\n<script>\nvar ABCAnalytics = {"nielsen":{"asset_id":243500,"section":"politics:impeachment","seg_a":"","seg_b":"","seg_c":"","debug":""},"chartbeat":{"uid":"12240","domain":"fivethirtyeight.com","path":"\\/features\\/what-weve-already-learned-from-the-democrats-impeachment-witnesses\\/","sections":"politics,features","authors":"Amelia Thomson-DeVeaux","title":"The Democrats\\u2019 Impeachment Witnesses","loadPubJS":false,"loadVidJS":true},"gtm":{"id":"GTM-KLHT6T2"},"omniture":{"pageName":"politics:features:what-weve-already-learned-from-the-democrats-impeachment-witnesses","prop1":"fivethirtyeight","prop2":"","prop5":"features","prop6":"Amelia Thomson-DeVeaux","prop7":"politics","prop8":"politics:impeachment","prop12":"The Democrats\\u2019 Impeachment Witnesses","prop13":"243500:The Democrats\\u2019 Impeachment Witnesses","prop14":"","prop15":"https:\\/\\/fivethirtyeight.com\\/features\\/what-weve-already-learned-from-the-democrats-impeachment-witnesses\\/","prop16":"https:\\/\\/fivethirtyeight.com\\/features\\/what-weve-already-learned-from-the ...

# %%
soup = BeautifulSoup(r.content, "html.parser")

# %%
soup.title
# Out:
# <title>The Democrats’ Impeachment Witnesses | FiveThirtyEight</title>

# %%
soup.title.text
# Out:
# 'The Democrats’ Impeachment Witnesses | FiveThirtyEight'

# %%
soup.find(name="h1", attrs={"class": "article-title article-title-single entry-title"})
# Out:
# <h1 class="article-title article-title-single entry-title">
# 									The Democrats’ Impeachment Witnesses								</h1>

# %% [markdown]
# ### Extracting the title of the article

# %%
soup.find("h1", {"class": "article-title article-title-single entry-title"}).text
# Out:
# '\n\t\t\t\t\t\t\t\t\tThe Democrats’ Impeachment Witnesses\t\t\t\t\t\t\t\t'

# %%
soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
# Out:
# 'The Democrats’ Impeachment Witnesses'

# %% [markdown]
# ### Fetching an image from the webpage

# %%
img_url = "https://fivethirtyeight.com/wp-content/uploads/2019/11/IMPEACHMENT-WITNESSES_BANNER.png"

# %%
Image(url=img_url)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2019/11/IMPEACHMENT-WITNESSES_BANNER.png"/>

# %%
r = requests.get(img_url)

with open("photo.jpg", "w+b") as fr:      # w: writing mode, b: binary mode
    fr.write(r.content)

# %%
Image("photo.jpg")

# %% [markdown]
# ### Extracting a list of article titles

# %%
url = "https://fivethirtyeight.com/features/"
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")

# %%
h2_list = soup.find_all(name="h2", attrs={"class": "article-title entry-title"})
h2_list
# Out:
# [<h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/gun-sales-are-surging-but-background-checks-arent-keeping-up/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature1">
#  				Gun Sales Are Surging, But Background Checks Aren’t Keeping Up			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/videos/confidence-interval-will-biden-choose-kamala-harris-as-his-vp/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature2">
#  				Confidence Interval: Will Biden Choose Kamala Harris As His VP?			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/the-players-to-watch-on-the-nba-teams-just-trying-to-hang-around/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature3">
#  				The Players To Watch On The NBA Teams Just Trying To Hang Around			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/what-trump-could-learn-from-nascar/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature4">
#  				What Trump Could Learn From NASCAR			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/how-the-nhls-new-format-changed-the-stanley-cup-race/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature5">
#  				How The NHL’s New Format Changed The Stanley Cup Race			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/the-senate-has-always-favored-smaller-states-it-just-didnt-help-republicans-until-now/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature6">
#  				The Senate Has Always Favored Smaller States. It Just Didn’t Help Republicans Until Now.			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/videos/how-bidens-vp-pick-could-shape-perceptions-of-the-ticket-overall/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature8">
#  				How Biden’s VP Pick Could Shape Perceptions Of The Ticket Overall			</a>
#  </h2>,
#  <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/nomar-garciaparras-full-career-wasnt-enough-for-cooperstown-but-it-was-still-damn-good/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature10">
#  				Nomar Garciaparra’s Full Career Wasn’t Enough For Cooperstown — But It Was Still Damn Good			</a>
#  </h2>]

# %%
len(h2_list)
# Out:
# 8

# %%
for element in h2_list:
    print(element.text.strip())
# Out:
# Gun Sales Are Surging, But Background Checks Aren’t Keeping Up
# Confidence Interval: Will Biden Choose Kamala Harris As His VP?
# The Players To Watch On The NBA Teams Just Trying To Hang Around
# What Trump Could Learn From NASCAR
# How The NHL’s New Format Changed The Stanley Cup Race
# The Senate Has Always Favored Smaller States. It Just Didn’t Help Republicans Until Now.
# How Biden’s VP Pick Could Shape Perceptions Of The Ticket Overall
# Nomar Garciaparra’s Full Career Wasn’t Enough For Cooperstown — But It Was Still Damn Good

# %%
urls = ["https://fivethirtyeight.com/features/"]

for i in range(2, 101):     # The range(2, 101) generates a list of integers from 2 to 100.
    url = "https://fivethirtyeight.com/features/page/{}/".format(i)
    urls.append(url)

# %%
for url in urls:
    print(url)              # Do whatever you want with each web page.
# Out:
# https://fivethirtyeight.com/features/
# https://fivethirtyeight.com/features/page/2/
# https://fivethirtyeight.com/features/page/3/
# https://fivethirtyeight.com/features/page/79/
# https://fivethirtyeight.com/features/page/80/
# https://fivethirtyeight.com/features/page/81/
# https://fivethirtyeight.com/features/page/82/
# https://fivethirtyeight.com/features/page/83/
# https://fivethirtyeight.com/features/page/84/
# https://fivethirtyeight.com/features/page/85/
# https://fivethirtyeight.com/features/page/86/
# https://fivethirtyeight.com/features/page/87/
# https://fivethirtyeight.com/features/page/88/
# https://fivethirtyeight.com/features/page/89/
# https://fivethirtyeight.com/features/page/90/
# https://fivethirtyeight.com/features/page/91/
# https://fivethirtyeight.com/features/page/92/
# https://fivethirtyeight.com/features/page/93/
# https://fivethirtyeight.com/features/page/94/
# https://fivethirtyeight.com/features/page/95/
# https://fivethirtyeight.com/features/page/96/
# https://fivethirtyeight.com/features/page/97/
# https://fivethirtyeight.com/features/page/98/
# https://fivethirtyeight.com/features/page/99/
# https://fivethirtyeight.com/features/page/100/

# %% [markdown]
# ### Writing & reading an HTML file

# %%
url = "https://fivethirtyeight.com/features/what-weve-already-learned-from-the-democrats-impeachment-witnesses/"
r = requests.get(url)

# %%
url[len("https://fivethirtyeight.com/features/"):-1]
# Out:
# 'what-weve-already-learned-from-the-democrats-impeachment-witnesses'

# %%
file_name = url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
file_name
# Out:
# 'what-weve-already-learned-from-the-democrats-impeachment-witnesses.html'

# %%
with open(file_name, "w+b") as fw:
    fw.write(r.content)

# %%
with open(file_name, "r+b") as fr:
    soup = BeautifulSoup(fr.read(), "html.parser")
    
    print(soup.title.text)
# Out:
# The Democrats’ Impeachment Witnesses | FiveThirtyEight

# %% [markdown]
# ### Automating the process of saving all articles on the Features list

# %%
if not os.path.isdir("HTMLs"):
    os.mkdir("HTMLs")

# %%
for url in urls[:10]:
    print(url)
    
    ####################################################
    # Get the content of a page
    ####################################################
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    
    ####################################################
    # Get the list of articles
    ####################################################
    h2_list = soup.find_all(name="h2", attrs={"class": "article-title entry-title"})
    
    for h2 in h2_list:
        ####################################################
        # Find the anchor tag
        ####################################################
        a = h2.find("a")
        
        ####################################################
        # Extract the title & URL of an article
        ####################################################
        title = a.text
        article_url = a["href"]
        
        ####################################################
        # Fetch the content and save it as an HTML file
        ####################################################
        r2 = requests.get(article_url)
                
        file_name = article_url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
        with open("HTMLs/" + file_name, "w+b") as f:
            f.write(r2.content)
        
        print("- " + file_name + " saved.")
        
        ####################################################
        # Sleep for a second
        ####################################################
        time.sleep(1)
    
    print()
# Out:
# https://fivethirtyeight.com/features/
# - gun-sales-are-surging-but-background-checks-arent-keeping-up.html saved.
# - nfidence-interval-will-biden-choose-kamala-harris-as-his-vp.html saved.
# - the-players-to-watch-on-the-nba-teams-just-trying-to-hang-around.html saved.
# - what-trump-could-learn-from-nascar.html saved.
# - how-the-nhls-new-format-changed-the-stanley-cup-race.html saved.
# - the-senate-has-always-favored-smaller-states-it-just-didnt-help-republicans-until-now.html saved.
# - w-bidens-vp-pick-could-shape-perceptions-of-the-ticket-overall.html saved.
# - roberts-is-the-new-swing-justice-that-doesnt-mean-hes-becoming-more-liberal.html saved.
# - leicester-city-seemed-like-a-sure-thing-for-the-champions-league-not-anymore.html saved.
# - e-covid-19-death-rate-is-rising-americans-disagree-with-trump-on-what-to-do-about-it.html saved.
# - the-houston-dash-have-something-to-prove.html saved.
# - how-the-experts-are-measuring-the-economic-recovery.html saved.
# - why-trump-not-biden-might-have-an-enthusiasm-problem.html saved.
#
# https://fivethirtyeight.com/features/page/7/
# - what-you-need-to-know-about-todays-elections-in-alabama-maine-and-texas.html saved.
# - white-democrats-are-wary-of-big-ideas-to-address-racial-inequality.html saved.
# - the-dodgers-legacy-may-depend-on-this-short-season.html saved.
# - -you-buy-that-voter-enthusiasm-will-help-trump-in-2020.html saved.
# - the-supreme-courts-big-rulings-were-surprisingly-mainstream-this-year.html saved.
# - nfidence-interval-could-trump-win-if-he-replaces-pence.html saved.
# - barcelona-is-struggling-is-messi-part-of-the-problem-or-the-solution.html saved.
# - e-supreme-court-justices-influenced-by-public-opinion.html saved.
# - if-talking-about-race-hurts-democrats-why-is-biden-so-far-ahead.html saved.
#
# https://fivethirtyeight.com/features/page/8/
# - if-talking-about-race-hurts-democrats-why-is-biden-so-far-ahead.html saved.
# - can-you-make-24.html saved.
# - -interview-with-dr-anthony-fauci.html saved.
# - were-not-going-to-see-trumps-tax-returns-anytime-soon.html saved.
# - bidens-polling-lead-is-big-and-steady.html saved.
# - america-is-testing-for-covid-19-more-than-ever-and-it-still-isnt-enough.html saved.
# - what-if-kevin-garnett-and-tracy-mcgrady-had-shot-threes-instead-of-long-twos.html saved.
# - 2020-could-be-the-new-year-of-the-woman-for-the-gop.html saved.
#
# https://fivethirtyeight.com/features/page/9/
# - w-trump-could-improve-his-electoral-odds.html saved.
# - economists-think-congress-could-create-an-economic-disaster-this-summer.html saved.
# - lou-whitaker-turned-a-damn-good-double-play.html saved.
# - were-hiring-a-part-time-social-media-producer.html saved.
# - bryson-dechambeaus-power-boost-is-off-the-charts.html saved.
# - -you-buy-that-masks-could-help-trump-politically.html saved.
# - why-counting-on-a-convention-bounce-this-year-is-risky.html saved.
# - voters-who-think-the-economy-is-the-countrys-biggest-problem-are-pretty-trumpy-that-might-not-help-him-much.html saved.
#
# https://fivethirtyeight.com/features/page/10/
# - voters-who-think-the-economy-is-the-countrys-biggest-problem-are-pretty-trumpy-that-might-not-help-him-much.html saved.
# - can-you-stay-in-your-lane.html saved.
# - the-unemployment-rate-is-falling-but-more-people-are-losing-their-jobs-permanently.html saved.
# - the-winners-and-losers-in-our-updated-nba-forecast.html saved.
# - the-science-of-mask-wearing-hasnt-changed-so-why-have-our-expectations.html saved.
# - when-proof-is-not-enough.html saved.
# - what-went-down-in-colorado-oklahoma-and-utah.html saved.
# - charles-booker-jamaal-bowman-and-the-7-competing-camps-in-black-politics.html saved.

# %% [markdown]
# ### Extracting information from all HTML files & saving it in a CSV file

# %%
os.listdir("HTMLs")
# Out:
# ['-interview-with-dr-anthony-fauci.html',
#  '-you-buy-that-coronavirus-will-be-what-makes-or-breaks-trumps-re-election-prospects.html',
#  'the-dodgers-lead-our-national-league-predictions-but-dont-count-out-the-nats-or-reds.html',
#  'the-dodgers-legacy-may-depend-on-this-short-season.html',
#  'the-houston-dash-have-something-to-prove.html',
#  'the-nwsl-is-about-to-crown-a-brand-new-champion.html',
#  'the-players-to-watch-on-the-nba-teams-just-trying-to-hang-around.html',
#  'the-science-of-mask-wearing-hasnt-changed-so-why-have-our-expectations.html',
#  'the-senate-has-always-favored-smaller-states-it-just-didnt-help-republicans-until-now.html',
#  'the-supreme-courts-big-rulings-were-surprisingly-mainstream-this-year.html',
#  'the-unemployment-rate-is-falling-but-more-people-are-losing-their-jobs-permanently.html',
#  'the-winners-and-losers-in-our-updated-nba-forecast.html',
#  'voters-who-think-the-economy-is-the-countrys-biggest-problem-are-pretty-trumpy-that-might-not-help-him-much.html',
#  'w-a-60-year-old-drug-became-our-best-hope-for-saving-people-with-covid-19.html',
#  'w-bidens-vp-pick-could-shape-perceptions-of-the-ticket-overall.html',
#  'w-trump-could-improve-his-electoral-odds.html',
#  'were-hiring-a-part-time-social-media-producer.html',
#  'were-looking-for-a-podcast-producer-for-podcast-19.html',
#  'were-not-going-to-see-trumps-tax-returns-anytime-soon.html',
#  'what-if-kevin-garnett-and-tracy-mcgrady-had-shot-threes-instead-of-long-twos.html',
#  'what-to-watch-for-on-the-english-premier-leagues-final-match-day.html',
#  'what-trump-could-learn-from-nascar.html',
#  'what-went-down-in-colorado-oklahoma-and-utah.html',
#  'what-you-need-to-know-about-todays-elections-in-alabama-maine-and-texas.html',
#  'when-does-a-pandemic-start-to-erode-civil-liberties.html',
#  'when-proof-is-not-enough.html',
#  'white-democrats-are-wary-of-big-ideas-to-address-racial-inequality.html',
#  'white-neighborhoods-have-more-access-to-covid-19-testing-sites.html',
#  'whos-who-in-the-nba-bubble-the-inner-circle-contenders.html',
#  'whos-who-in-the-nba-bubble-the-potential-party-crashers.html',
#  'whos-who-in-the-nba-bubble-the-teams-just-along-for-the-ride.html',
#  'why-blaming-china-for-the-pandemic-probably-wont-help-trump-win.html',
#  'why-counting-on-a-convention-bounce-this-year-is-risky.html',
#  'why-florida-could-go-blue-in-2020.html',
#  'why-it-took-so-long-for-politicians-to-treat-the-child-care-crisis-as-a-crisis.html',
#  'why-trump-not-biden-might-have-an-enthusiasm-problem.html',
#  'will-the-mystics-repeat-will-the-storm-surge-what-to-watch-in-the-wnba-bubble.html',
#  'winners-and-losers-in-mlbs-new-playoff-format.html',
#  'yes-biden-has-a-big-lead-but-its-probably-not-15-points.html']

# %%
# with open("metadata.csv", "w", encoding="utf8") as fw:
#     ####################################################
#     # Field names on the first row
#     ####################################################
#     fw.write("file_name\tarticle_title\tarticle_author\n")

#     for file_name in os.listdir("HTMLs"):
#         ####################################################
#         # Field values starting from the second row
#         ####################################################
#         with open("HTMLs/" + file_name, "r+b") as fr:
#             print(file_name)
#             soup = BeautifulSoup(fr.read(), "html.parser")
#             article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
#             #article_author = soup.find("a", {"class": "author url fn"}).text
            
#             ####################################################
#             # Remove all possible tabs
#             ####################################################
#             article_title = article_title.replace("\t", "")
#             article_aurthor = article_author.replace("\t", "")
            
#             fw.write("{}\t{}\t{}\n".format(file_name, article_title, article_author))

# %%
with open("metadata.csv", "w", encoding="utf8") as fw:
    ####################################################
    # Field names on the first row
    ####################################################
    fw.write("file_name\tarticle_title\tarticle_author\n")

    for file_name in os.listdir("HTMLs"):
        ####################################################
        # Field values starting from the second row
        ####################################################
        with open("HTMLs/" + file_name, "r+b") as fr:
            print(file_name)
            soup = BeautifulSoup(fr.read(), "html.parser")
            article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
            
            ####################################################
            # No author exception handling
            ####################################################
            if soup.find("a", {"class": "author url fn"}) is None:
                article_author = ""
            else:
                article_author = soup.find("a", {"class": "author url fn"}).text
            
            ####################################################
            # Remove all possible tabs
            ####################################################
            article_title = article_title.replace("\t", "")
            article_aurthor = article_author.replace("\t", "")
                        
            fw.write("{}\t{}\t{}\n".format(file_name, article_title, article_author))
# Out:
# -interview-with-dr-anthony-fauci.html
# -you-buy-that-coronavirus-will-be-what-makes-or-breaks-trumps-re-election-prospects.html
# -you-buy-that-mail-in-voting-will-hurt-republicans.html
# -you-buy-that-masks-could-help-trump-politically.html
# -you-buy-that-voter-enthusiasm-will-help-trump-in-2020.html
# 2020-could-be-the-new-year-of-the-woman-for-the-gop.html
# america-is-testing-for-covid-19-more-than-ever-and-it-still-isnt-enough.html
# americans-increasingly-dislike-how-republican-governors-are-handling-the-coronavirus-outbreak.html
# americans-support-voting-by-mail-but-not-all-of-them-want-to-or-can.html
# are-you-a-pinball-wizard.html
# barcelona-is-struggling-is-messi-part-of-the-problem-or-the-solution.html
# baseball-will-be-weird-this-year-but-the-astros-and-yankees-are-favorites-in-the-american-league-again.html
# bernie-williams-deserves-more-credit-for-making-the-yankees-a-dynasty.html
# bidens-polling-lead-is-big-and-steady.html
# bryson-dechambeaus-power-boost-is-off-the-charts.html
# can-the-hare-beat-the-tortoise.html
# can-you-make-24.html
# can-you-stay-in-your-lane.html
# canceled-races-arent-stopping-endurance-athletes-from-setting-wild-new-records.html
# charles-booker-jamaal-bowman-and-the-7-competing-camps-in-black-politics.html
# cret-trump-voters-didnt-decide-2016-and-probably-wont-swing-2020.html
# e-covid-19-death-rate-is-rising-americans-disagree-with-trump-on-what-to-do-about-it.html
# e-supreme-court-justices-influenced-by-public-opinion.html
# economists-think-congress-could-create-an-economic-disaster-this-summer.html
# economists-think-congress-should-keep-paying-unemployed-workers-600-a-week-or-even-more.html
# every-decision-is-a-risk-every-risk-is-a-decision.html
# for-aspiring-performers-the-nba-is-the-best-place-to-be-a-mascot.html
# gun-sales-are-surging-but-background-checks-arent-keeping-up.html
# how-can-a-senator-vote-with-trump-most-of-the-time-and-still-be-a-moderate.html
# how-much-talent-is-the-wnba-missing-this-season.html
# how-the-experts-are-measuring-the-economic-recovery.html
# how-the-nhls-new-format-changed-the-stanley-cup-race.html
# how-the-pandemic-could-force-a-generation-of-mothers-out-of-the-workforce.html
# how-to-make-indoor-air-safer.html
# how-we-analyzed-7914-covid-19-testing-sites-and-found-racial-disparities.html
# if-talking-about-race-hurts-democrats-why-is-biden-so-far-ahead.html
